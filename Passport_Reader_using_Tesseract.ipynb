# %% [markdown]
# ### Author : A. N. M. Sajedul Alam
#
# ### Goal : Extracting information from sample random passports from both pdf and jpg file extensions

# %%
# !sudo apt install tesseract-ocr
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 27 not upgraded.
# Need to get 4,795 kB of archives.
# After this operation, 15.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-eng all 4.00~git24-0e00fe6-1.2 [1,588 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-osd all 4.00~git24-0e00fe6-1.2 [2,989 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr amd64 4.00~git2288-10f4998a-2 [218 kB]
# ...

# %%
# !pip install pytesseract
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 3.1 MB 4.2 MB/s
# ...
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
# ...

# %% [markdown]
# ### For JPG File Extensions

# %%
import pytesseract
import shutil
import os
import random
try:
    from PIL import Image
except ImportError:
    import Image

# %% [markdown]
# ### For Passport No: 7

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-5aed1f7d-fc51-4d29-94d7-e4f70fc5bd44" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5aed1f7d-fc51-4d29-94d7-e4f70fc5bd44">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
extractedInformation = pytesseract.image_to_string(Image.open('7.jpg'))

# %%
print(extractedInformation)
# Out:
#
#
#
#
#
#
#
#
#
#
# @STIBICH MARTINS
#
# Vornamen/ Gin namen:Prémems
#
# YHAICHA LUZIA
#
# ioate ct sith) Stastaameenarineny ators
# Sote'de aaineance Rema
#
# 22.11.1999 DEUTSCH
# Sebunsor
#
# css wari 6 mance
# BRASILIA
# sett
# 17.11.2025 S255
#
# \Unterachein der nnabern/ des nae
# Srterecte eae Snatiee ae a Wain! fare

# %% [markdown]
# ### For Passport No: 6

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4cea5ef7-a048-41a5-9f4b-603480b5a1f6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4cea5ef7-a048-41a5-9f4b-603480b5a1f6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
extractedInformation = pytesseract.image_to_string(Image.open('6.jpg'))

# %%
print(extractedInformation)
# Out:
# AZARBAYCAN RESPUBLIKASI - REPUBLIC OF AZERBAJAN
#
# WEE PASPORT Tite Olkanin kodu/Code of State Pasportun nomrasi/Passport No
# Ge passpoRT PC AZE X11000344
# Soyadi/Sumame
# HUSEYNLI
#
# HUSEYNLI
#
# ‘Adi, atasinin adi/Civen name, patronymic
#
# ORXAN MOMMOD OGLU
# ORKHAN
#
# Yatandashii/Nationality
#
# AZORBAYCAN/AZERBAIJAN
#
# Doguldudu tarix/Date of birth Fadi identifikasiya ndmrasi/PersonalNo _Cinsi/Sex
#
# 15.03.1975 30LUV5Z K/M
#
# Dogjuldugu yer/Place of bith
#
# AZORBAYCAN/AZE
#
# Verilma tarixi/Date of issue Etibariliq middati/Date of expiry, Pasportsahibinin imzasi/Holder's signature
# 02.08.2013 01.08.2023
# eal * Pasportu veran organ/tssuing authority ,
# 182025 DAXILI ISLOR NAZIRLIY! Za
# MINISTRY OF INTERNAL AFFAIRS
#
# PCAZEHUSEYNLI<<ORKHANK<X<<<<<<<<<<<<<<<<<<<<<<
# X110003442AZE7503153M230801030LJV5Z<<<<<<<86
#
#
#
# SPECIMEN
#
#
#
#
#
# SS PTTTEINITITY

# %% [markdown]
# ### For Passport No: 5

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0780c6cc-9108-4dee-b932-d11f756d90d2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0780c6cc-9108-4dee-b932-d11f756d90d2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
extractedInformation = pytesseract.image_to_string(Image.open('5.jpg'))

# %%
print(extractedInformation)
# Out:
#
#
# Rzeczpospolita Polska ‘Reptitie ot Poland
# Dowéd osobist: Identity card
# se s
#
# IMIONA 7 GIVEN NaMes
# AGNIESZKA IZABELA
#
# NAZHNISKO RODOWE / FAMIY NAME
#
# RZESZOWIAK
#
# IMIONA RODZICOW./ PARENTS: civENNAiiEs
# JACEK ANNA a

# %% [markdown]
# ### For Passport No: 4

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6f5e1a99-cf44-4167-98a9-dc2fe0a30bac" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6f5e1a99-cf44-4167-98a9-dc2fe0a30bac">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
extractedInformation = pytesseract.image_to_string(Image.open('4.jpg'))

# %%
print(extractedInformation)
# Out:
# BUNDESREPUBL tic DEUTSCHLAND
#
# FEDERAL REPUBLIC OF GERMANY. / REPU! JE FEDERALE D'ALLEMAGNE.
#
# PERSONALAUSWEIS
#
# IDENTITY CARD/ CARTE D'IDENTITE
#
# _—
# “e
#
# “—
# 7.
#
# T52400179
#
# Staatoan jehorigkeit/Nationality/
# Sraneange ty!

# %% [markdown]
# ### For Passport No: 3

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4e14ccc9-3200-4993-8d15-8912d0f3fd46" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4e14ccc9-3200-4993-8d15-8912d0f3fd46">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
extractedInformation = pytesseract.image_to_string(Image.open('3.jpg'))

# %%
print(extractedInformation)
# Out:
# Haein! Serene, Mom
#
# soars aS I STER
#
# MUSTERMANN
# eee naereary Greet mare Pr bene
#
# ERIKA
#
# Cater athg wed ere’ Date ate phnew ot berth « .
#
# 12.08.64 MUNCHEN
# See te
#
# Duty te oe eRe
#
# DEUTSCH / O7.
#
# el STER
#
# IDD<<MUSTERMANN<<ERIKA<<<<<<<KKKeKK<
# 12200015180<<6408125<1110078<<<<<<<0

# %% [markdown]
# ### For Passport No: 2

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e949a256-2027-4233-994f-fc5e277ba727" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e949a256-2027-4233-994f-fc5e277ba727">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
extractedInformation = pytesseract.image_to_string(Image.open('2.jpg'))

# %%
print(extractedInformation)
# Out:
# BUNDESREPUBLIK DEUTSCHLAND LGO GV
#
# FEDERAL REPUBLIC OF GERMANY / REPUBLIQUE FEDERALE D'ALLEMAGNE
#
# PERSONAL AUSWEIS fe] omerSumame/
#
# 1D CARTE DIDENTITE Burtsname’Name at bith/Nom de naissance
#
# we
#
#
#
# JURGEN
#
# Gebustsng/Date of bith’ Stanteangehigkel/Natonaty
#
# ‘toe Vos 25... 19 DEUTSCH
#
# # —coBURG
# sae
# 09.02.2031 1 ¢
#
# LYoterschrtt der inhabgrin/des Inhabers
# Snatore otbearer” Signature do a Wtulaie/du thule
#
# tt
#
# Js

# %% [markdown]
# ### For Passport No: 1

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2c43e65f-b4ff-4882-b009-34d12838c638" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2c43e65f-b4ff-4882-b009-34d12838c638">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
extractedInformation = pytesseract.image_to_string(Image.open('1.jpg'))

# %%
print(extractedInformation)
# Out:
# RerryoarBreanrevwernrt 095302376
#
# MUSTERMANN
# veeamenore amen Pee
#
# ~ ERIKA / i
# Cenrg td nt rt i ce
#
# 12.08.64 BERLIN
# Stuamanoaigeinansety! —— Gaty baat mr vOam epi
#
# “DEUTSCH 431.10. 2017 |
#
# TT aMSTER
#
# IDD<<MUSTERMANN<<ERIKAC<<<<<<<<<<<xce

# %% [markdown]
# ### For Pdf File Extensions

# %% [markdown]
# ### For All 7 Passports in 1 PDF

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-76d13bf7-e1cc-44fd-8135-481ec7f373ba" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-76d13bf7-e1cc-44fd-8135-481ec7f373ba">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install pdf2image
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !sudo apt-get install poppler-utils
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 27 not upgraded.
# Need to get 154 kB of archives.
# After this operation, 613 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 poppler-utils amd64 0.62.0-2ubuntu2.14 [154 kB]
# Fetched 154 kB in 1s (123 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# ...

# %%
import os
from PIL import Image
from pdf2image import convert_from_path
import pytesseract

filePath = '/content/all_7_passports.pdf'
doc = convert_from_path(filePath)
path, fileName = os.path.split(filePath)
fileBaseName, fileExtension = os.path.splitext(fileName)

for page_number, page_data in enumerate(doc):
    txt = pytesseract.image_to_string(page_data).encode("utf-8")
    print("Page # {} - {}".format(str(page_number),txt))
# Out:
# Page # 0 - b'  \n\n \n \n\n4 Rzeczpospolita Polska republic of Poland (\nor E : . ~: Pe \xe2\x80\x94\nDow\xc3\xa96d OSObisty identity card\n\n  \n\nIMIONA/ GIVEN NAMES \xe2\x80\x9c&\nAGNIESZKA IZABELA\nNAZWISKO RODOWE / FAMILY NAME\nRZESZOWIAK\n\x0c'
# ...
